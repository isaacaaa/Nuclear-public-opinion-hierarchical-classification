# %%
# !git clone https://github.com/isaacaaa/Nuclear-public-opinion-hierarchical-classification.git
# Out:
# Cloning into 'Nuclear-public-opinion-hierarchical-classification'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 27 (delta 12), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
cd Nuclear-public-opinion-hierarchical-classification/
# Out:
# /content/Nuclear-public-opinion-hierarchical-classification

# %%
# !pip install transformers==3.0.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 769 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 48.3 MB/s
# ...
#      |████████████████████████████████| 880 kB 55.4 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 51.4 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=470b8000c8cf57db2a7caecc4c20694badaf60c703a11ef68836f11a416bc7ce
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# ...

# %%
# %run run_bert_base.py
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# WARNING:__main__:Process rank: -1, device: cpu, n_gpu: 0, distributed training: False, 16-bits training: False
# Downloading:   0%|          | 0.00/624 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/412M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/Nuclear-public-opinion-hierarchical-classification/run_bert_base.py in <module>
#     763
#     764 if __name__ == "__main__":
# --> 765     main()
#     766
#
# /content/Nuclear-public-opinion-hierarchical-classification/run_bert_base.py in main()
#     689     config.num_labels2 = len(label_list2)
#     690
# --> 691     model = model_class.from_pretrained(
# ...

# %%
# %run evaluate.py
